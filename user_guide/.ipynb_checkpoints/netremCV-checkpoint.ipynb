# %% [markdown]
# # netremCV
# Cross-validation approach for estimating the optimal $\beta_{net}$ and $\alpha_{lasso}$.
#
# Selection for $\beta_{net}$ can impact the optimal values for $\alpha_{net}$

# %%
import sys
sys.path.append("../code")  # assuming "code" is one directory up and then down into "code"

from DemoDataBuilderXandY import generate_dummy_data
from Netrem_model_builder import netrem, netremCV
import PriorGraphNetwork as graph
import error_metrics as em 
import essential_functions as ef
import netrem_evaluation_functions as nm_eval
import Netrem_model_builder as nm

dummy_data = generate_dummy_data(corrVals = [0.9, 0.5, 0.3, -0.2, -0.8],
                                 num_samples_M = 100000,
                                 train_data_percent = 70)
# Out:
# :) same_train_test_data = False
# Please note that since we hold out 30.0% of our 100000 samples for testing, we have:
# X_train = 70000 rows (samples) and 5 columns (N = 5 predictors) for training.
# X_test = 30000 rows (samples) and 5 columns (N = 5 predictors) for testing.
# y_train = 70000 corresponding rows (samples) for training.
# y_test = 30000 corresponding rows (samples) for testing.
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 557.68it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 994.05it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1684.73it/s]

# %%
# 70 samples for training data (used to train and fit GRegulNet model)
X_train = dummy_data.view_X_train_df()
y_train = dummy_data.view_y_train_df()

# 30 samples for testing data
X_test = dummy_data.view_X_test_df()
y_test = dummy_data.view_y_test_df()

# %%
# prior network edge_list:
edge_list = [["TF1", "TF2", 0.9], ["TF4", "TF5", 0.75], ["TF1", "TF3"], ["TF1", "TF4"], ["TF1", "TF5"], 
             ["TF2", "TF3"], ["TF2", "TF4"], ["TF2", "TF5"], ["TF3", "TF4"], ["TF3", "TF5"]]
edge_list
# Out:
# [['TF1', 'TF2', 0.9],
#  ['TF4', 'TF5', 0.75],
#  ['TF1', 'TF3'],
#  ['TF1', 'TF4'],
#  ['TF1', 'TF5'],
#  ['TF2', 'TF3'],
#  ['TF2', 'TF4'],
#  ['TF2', 'TF5'],
#  ['TF3', 'TF4'],
#  ['TF3', 'TF5']]

# %%
# %%time 

netrem_demoCV = netremCV(edge_list = edge_list, X = X_train, y = y_train) 
netrem_demoCV
# Out:
# :) using variance to define beta_net values
# beta_min = 1.1506396943803596 and beta_max = 115.06396943803597
# :) Generating beta_net and alpha_lasso pairs:   0%|          | 0/50 [00:00<?, ?it/s]
# :) Performing NetREmCV with both beta_network and alpha_lasso as UNKNOWN.
#   0%|          | 0/50 [00:00<?, ?it/s]
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] END alpha_lasso=0.051694590434151706, beta_net=115.06396943803597; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=115.06396943803597; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=115.06396943803597; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=115.06396943803597; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=115.06396943803597; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=104.74252173191628; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=104.74252173191628; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=104.74252173191628; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=104.74252173191628; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=104.74252173191628; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=95.34692669080077; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=95.34692669080077; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=95.34692669080077; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=95.34692669080077; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=95.34692669080077; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=86.79413364372718; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=86.79413364372718; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=86.79413364372718; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=86.79413364372718; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=86.79413364372718; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=79.0085417162375; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=79.0085417162375; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=79.0085417162375; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=79.0085417162375; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=79.0085417162375; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=71.92133157005813; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=71.92133157005813; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=71.92133157005813; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=71.92133157005813; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=71.92133157005813; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=65.46985708694802; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=65.46985708694802; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=65.46985708694802; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=65.46985708694802; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=65.46985708694802; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=59.59709161961414; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=59.59709161961414; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=59.59709161961414; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=59.59709161961414; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=59.59709161961414; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=54.25112391492854; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=54.25112391492854; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=54.25112391492854; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=54.25112391492854; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=54.25112391492854; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=49.38469925375173; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=49.38469925375173; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=49.38469925375173; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=49.38469925375173; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=49.38469925375173; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=44.954801751349464; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=44.954801751349464; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=44.954801751349464; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=44.954801751349464; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=44.954801751349464; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=40.922274126223485; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=40.922274126223485; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=40.922274126223485; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=40.922274126223485; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=40.922274126223485; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=37.25147157637083; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=37.25147157637083; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=37.25147157637083; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=37.25147157637083; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=37.25147157637083; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=33.90994670347335; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=33.90994670347335; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=33.90994670347335; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=33.90994670347335; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=33.90994670347335; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=30.8681626999614; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=30.8681626999614; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=30.8681626999614; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=30.8681626999614; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=30.8681626999614; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=28.09923226372073; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=28.09923226372073; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=28.09923226372073; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=28.09923226372073; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=28.09923226372073; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=25.578679932625565; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=25.578679932625565; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=25.578679932625565; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=25.578679932625565; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=25.578679932625565; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=23.28422573809735; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=23.28422573809735; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=23.28422573809735; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=23.28422573809735; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=23.28422573809735; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=21.195588265333313; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=21.195588265333313; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=21.195588265333313; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=21.195588265333313; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=21.195588265333313; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=19.294305379391396; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=19.294305379391396; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=19.294305379391396; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=19.294305379391396; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=19.294305379391396; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=17.563571032472005; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=17.563571032472005; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=17.563571032472005; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=17.563571032472005; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=17.563571032472005; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=15.988086709883937; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=15.988086709883937; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=15.988086709883937; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=15.988086709883937; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=15.988086709883937; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=14.55392620157782; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=14.55392620157782; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=14.55392620157782; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=14.55392620157782; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=14.55392620157782; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=13.248412503919358; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=13.248412503919358; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=13.248412503919358; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=13.248412503919358; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=13.248412503919358; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=12.060005763597886; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=12.060005763597886; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=12.060005763597886; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=12.060005763597886; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=12.060005763597886; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=10.978201273170408; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=10.978201273170408; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=10.978201273170408; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=10.978201273170408; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=10.978201273170408; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=9.99343661659123; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=9.99343661659123; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=9.99343661659123; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=9.99343661659123; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=9.99343661659123; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=9.097007143956755; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=9.097007143956755; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=9.097007143956755; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=9.097007143956755; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=9.097007143956755; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=8.280989028319691; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=8.280989028319691; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=8.280989028319691; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=8.280989028319691; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=8.280989028319691; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=7.538169224447198; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=7.538169224447198; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=7.538169224447198; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=7.538169224447198; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=7.538169224447198; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=6.8619817104060505; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=6.8619817104060505; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=6.8619817104060505; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=6.8619817104060505; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=6.8619817104060505; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=6.246449448393774; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=6.246449448393774; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=6.246449448393774; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=6.246449448393774; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=6.246449448393774; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=5.686131551788998; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=5.686131551788998; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=5.686131551788998; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=5.686131551788998; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=5.686131551788998; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=5.17607519141363; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=5.17607519141363; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=5.17607519141363; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=5.17607519141363; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=5.17607519141363; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=4.711771815890945; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=4.711771815890945; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=4.711771815890945; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=4.711771815890945; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=4.711771815890945; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=4.289117299117333; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=4.289117299117333; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=4.289117299117333; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=4.289117299117333; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=4.289117299117333; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=3.904375662578425; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=3.904375662578425; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=3.904375662578425; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=3.904375662578425; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=3.904375662578425; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=3.554146051839581; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=3.554146051839581; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=3.554146051839581; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=3.554146051839581; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=3.554146051839581; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=3.235332675305331; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=3.235332675305331; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=3.235332675305331; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=3.235332675305331; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=3.235332675305331; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=2.94511743952688; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=2.94511743952688; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=2.94511743952688; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=2.94511743952688; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=2.94511743952688; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=2.6809350391723745; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=2.6809350391723745; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=2.6809350391723745; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=2.6809350391723745; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=2.6809350391723745; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=2.4404502814722417; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=2.4404502814722417; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=2.4404502814722417; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=2.4404502814722417; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=2.4404502814722417; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=2.221537444703078; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=2.221537444703078; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=2.221537444703078; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=2.221537444703078; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=2.221537444703078; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=2.022261488253153; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=2.022261488253153; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=2.022261488253153; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=2.022261488253153; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=2.022261488253153; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=1.8408609481792693; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=1.8408609481792693; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=1.8408609481792693; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=1.8408609481792693; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=1.8408609481792693; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=1.675732367063334; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=1.675732367063334; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=1.675732367063334; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=1.675732367063334; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=1.675732367063334; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=1.525416120539173; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=1.525416120539173; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=1.525416120539173; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=1.525416120539173; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=1.525416120539173; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=1.3885835152057047; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=1.3885835152057047; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=1.3885835152057047; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=1.3885835152057047; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=1.3885835152057047; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=1.2640250438808156; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=1.2640250438808156; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=1.2640250438808156; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=1.2640250438808156; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=1.2640250438808156; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=1.1506396943803596; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=1.1506396943803596; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=1.1506396943803596; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=1.1506396943803596; total time=   0.0s
# [CV] END alpha_lasso=0.051694590434151706, beta_net=1.1506396943803596; total time=   0.0s
# :) NetREmCV found that the optimal alpha_lasso = 0.051694590434151706 and optimal beta_net = 1.1506396943803596
# :) Please note that the training Mean Square Error (MSE) from this fitted NetREm model is 0.13727397681026726
# CPU times: total: 5min 10s
# Wall time: 5min 13s
# NetREmModel(overlapped_nodes_only=False, all_pos_coefs=False, y_intercept=False, max_lasso_iterations=10000, view_network=False, tolerance=0.0001, lasso_selection=cyclic, beta_net=1.1506396943803596, alpha_lasso=0.051694590434151706, network=<PriorGraphNetwork.PriorGraphNetwork object at 0x00000202249230A0>)

# %%
netrem_demoCV
# Out:
# NetREmModel(overlapped_nodes_only=False, all_pos_coefs=False, y_intercept=False, max_lasso_iterations=10000, view_network=False, tolerance=0.0001, lasso_selection=cyclic, beta_net=1.1506396943803596, alpha_lasso=0.051694590434151706, network=<PriorGraphNetwork.PriorGraphNetwork object at 0x00000202249230A0>)

# %%
netrem_demoCV.get_params()
# Out:
# {'info': 'NetREm Model',
#  'alpha_lasso': 0.051694590434151706,
#  'beta_net': 1.1506396943803596,
#  'y_intercept': False,
#  'model_type': 'Lasso',
#  'max_lasso_iterations': 10000,
#  'network': <PriorGraphNetwork.PriorGraphNetwork at 0x20224922950>,
#  'verbose': False,
#  'all_pos_coefs': False,
#  'model_info': 'fitted_model :)',
#  'target_gene_y': 'y',
#  'tolerance': 0.0001,
#  'lasso_selection': 'cyclic'}

# %%
netrem_demoCV.test_mse(X_train, y_train)
# Out:
# 0.13727397681026726

# %%
netrem_demoCV.test_mse(X_test, y_test)
# Out:
# 0.13781162327050317

# %%
netrem_demoCV.model_nonzero_coef_df
# Out:
#   y_intercept       TF1       TF2      TF3       TF5
# 0        None  0.277752  0.063378  0.00145 -0.159248

# %%
netrem_demoCV.B_interaction_df
# Out:
#           TF1       TF2        TF3       TF4       TF5
# TF1  5.414075  1.113261   0.361368 -0.429737 -2.771125
# TF2  1.113261  1.439763  -0.107738 -0.125070 -0.773506
# TF3  0.361368 -0.107738  37.921695 -0.359079 -0.715906
# TF4 -0.429737 -0.125070  -0.359079  1.139272  0.197285
# TF5 -2.771125 -0.773506  -0.715906  0.197285  2.877027

# %%
b_matrix = nm.organize_B_interaction_network(netrem_demoCV)
b_matrix
# Out:
#     TF1  TF2  B_train_weight sign potential_interaction  absVal_B  \
# 20  TF1  TF5       -2.771125   :(    :( competitive (-)  2.771125
# 4   TF5  TF1       -2.771125   :(    :( competitive (-)  2.771125
# 5   TF1  TF2        1.113261   :)                    :(  1.113261
# 1   TF2  TF1        1.113261   :)                    :(  1.113261
# 9   TF5  TF2       -0.773506   :(    :( competitive (-)  0.773506
# 21  TF2  TF5       -0.773506   :(    :( competitive (-)  0.773506
# 14  TF5  TF3       -0.715906   :(    :( competitive (-)  0.715906
# 22  TF3  TF5       -0.715906   :(    :( competitive (-)  0.715906
# 15  TF1  TF4       -0.429737   :(    :( competitive (-)  0.429737
# 3   TF4  TF1       -0.429737   :(    :( competitive (-)  0.429737
# 2   TF3  TF1        0.361368   :)                    :(  0.361368
# 10  TF1  TF3        0.361368   :)                    :(  0.361368
# 13  TF4  TF3       -0.359079   :(    :( competitive (-)  0.359079
# 17  TF3  TF4       -0.359079   :(    :( competitive (-)  0.359079
# 19  TF5  TF4        0.197285   :)                    :(  0.197285
# 23  TF4  TF5        0.197285   :)                    :(  0.197285
# 8   TF4  TF2       -0.125070   :(    :( competitive (-)  0.125070
# 16  TF2  TF4       -0.125070   :(    :( competitive (-)  0.125070
# 7   TF3  TF2       -0.107738   :(    :( competitive (-)  0.107738
# 11  TF2  TF3       -0.107738   :(    :( competitive (-)  0.107738
#
#                               info  candidate_TFs_N target_gene_y  \
# 20  B matrix of TF-TF interactions                5             y
# 4   B matrix of TF-TF interactions                5             y
# 5   B matrix of TF-TF interactions                5             y
# 1   B matrix of TF-TF interactions                5             y
# 9   B matrix of TF-TF interactions                5             y
# 21  B matrix of TF-TF interactions                5             y
# 14  B matrix of TF-TF interactions                5             y
# 22  B matrix of TF-TF interactions                5             y
# 15  B matrix of TF-TF interactions                5             y
# 3   B matrix of TF-TF interactions                5             y
# 2   B matrix of TF-TF interactions                5             y
# 10  B matrix of TF-TF interactions                5             y
# 13  B matrix of TF-TF interactions                5             y
# 17  B matrix of TF-TF interactions                5             y
# 19  B matrix of TF-TF interactions                5             y
# 23  B matrix of TF-TF interactions                5             y
# 8   B matrix of TF-TF interactions                5             y
# 16  B matrix of TF-TF interactions                5             y
# 7   B matrix of TF-TF interactions                5             y
# 11  B matrix of TF-TF interactions                5             y
#
#     num_final_predictors model_type  beta_net                      gene_data  \
# 20                     4      Lasso   1.15064  training gene expression data
# 4                      4      Lasso   1.15064  training gene expression data
# 5                      4      Lasso   1.15064  training gene expression data
# 1                      4      Lasso   1.15064  training gene expression data
# 9                      4      Lasso   1.15064  training gene expression data
# 21                     4      Lasso   1.15064  training gene expression data
# 14                     4      Lasso   1.15064  training gene expression data
# 22                     4      Lasso   1.15064  training gene expression data
# 15                     4      Lasso   1.15064  training gene expression data
# 3                      4      Lasso   1.15064  training gene expression data
# 2                      4      Lasso   1.15064  training gene expression data
# 10                     4      Lasso   1.15064  training gene expression data
# 13                     4      Lasso   1.15064  training gene expression data
# 17                     4      Lasso   1.15064  training gene expression data
# 19                     4      Lasso   1.15064  training gene expression data
# 23                     4      Lasso   1.15064  training gene expression data
# 8                      4      Lasso   1.15064  training gene expression data
# 16                     4      Lasso   1.15064  training gene expression data
# 7                      4      Lasso   1.15064  training gene expression data
# 11                     4      Lasso   1.15064  training gene expression data
#
#     rank  percentile
# 20   1.0        95.0
# 4    1.0        95.0
# 5    3.0        85.0
# 1    3.0        85.0
# 9    5.0        75.0
# 21   5.0        75.0
# 14   7.0        65.0
# 22   7.0        65.0
# 15   9.0        55.0
# 3    9.0        55.0
# 2   11.0        45.0
# 10  11.0        45.0
# 13  13.0        35.0
# 17  13.0        35.0
# 19  15.0        25.0
# 23  15.0        25.0
# 8   17.0        15.0
# 16  17.0        15.0
# 7   19.0         5.0
# 11  19.0         5.0
